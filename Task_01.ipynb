# %% [markdown]
# #### Name                  :  Zonia
#
# #### Roll no                :  211980001
#
# #### Assignment no :  01
#
# #### Course               :  Introduction to Data Science

# %% [markdown]
# Pandas Functions

# %% [markdown]
# * Import pandas library and read the csv file...

# %%
import pandas as pd
df = pd.read_csv("Dummy_Sales_Data_v1.csv")

# %% [markdown]
# * Printing the whole dataset...

# %% [markdown]
# ##### Pandas Functions to get an Overview of the Dataset...

# %%
df
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.head() :

# %% [markdown]
# * This function helps you to get the first few rows of the dataset. By default, it returns the first 5     rows. However, you can change this number by simply mentioning the desired number of rows in df.head()
# * For example, suppose you want to retrieve the first 6 rows of the dataset. You can get it below.

# %%
df.head(6)
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# ...

# %% [markdown]
# ### df.tail() :

# %% [markdown]
# * This function helps you to get the last few rows of the dataset. By default, it returns the last 5       rows, and similar to .head(), you can simply mention the desired number of rows in df.tail()
# * For example, suppose you want to retrieve the last 3 rows of the dataset. You can get it
#   below.

# %%
df.tail(8)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9991  4936610000999949366         6             183        Shipped
# 9992  3733010000999937330        28             160        Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9991  2021-11-16           Office          Emma                  26
# 9992  2021-09-27          Fashion       Anthony                  21
# 9993  2021-09-21    Entertainment          Emma                  33
# 9994  2021-10-16             Home         Sofia                  20
# ...

# %% [markdown]
# ### df.sample() :

# %% [markdown]
# * This function is used to get a randomly selected row, column, or both from a dataset. df.sample() takes   7 optional parameters, which means this function can be run without using any argument as below.

# %%
df.sample()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 5579  1653010000999916530        28             128  Not Shipped  2021-11-21
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 5579           Office       Kristen                  34                 23.0
#
#      Shipping_Address Product_Code  OrderCode
# 5579               UK        O-901     445221

# %% [markdown]
# * As you can see, this returned only a single row output. You can also specify the desired number of rows, and those many rows will be randomly selected.

# %% [markdown]
# ### df.info() :

# %% [markdown]
# * This function returns a quick summary of the DataFrame. This includes information about column names     and their respective data types, missing values, and memory consumption by DataFrame, as shown below.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# * So ideally, this function covers all the information which can be retrieved by individual methods such   as df.dtypes, df.columns, df.shape.

# %% [markdown]
# ### df.describe() :

# %% [markdown]
# * This function returns descriptive statistics about the data. This includes minimum, maximum, mean         (central tendency), standard deviation (dispersion) of the values in numerical columns, and the count     of all non-null values in the data, as shown below.

# %%
df.describe()
# Out:
#             OrderID     Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# count  9.999000e+03  9999.000000     9999.000000         9999.000000
# mean   3.020951e+18    50.739874      175.620662           27.571857
# std    1.167549e+18    29.005532       43.527995            4.610452
# min    1.010010e+18     1.000000      100.000000           20.000000
# 25%    2.010410e+18    26.000000      138.000000           24.000000
# 50%    3.002410e+18    51.000000      176.000000           28.000000
# 75%    4.024510e+18    76.000000      213.000000           32.000000
# max    5.049610e+18   100.000000      250.000000           35.000000
#
#        Delivery_Time(Days)      OrderCode
# count          9948.000000    9999.000000
# mean             17.518396  444682.917392
# std               4.609531     525.343171
# min              10.000000  443880.000000
# 25%              14.000000  444222.000000
# 50%              18.000000  444772.000000
# 75%              22.000000  445113.000000
# ...

# %% [markdown]
# ##### Pandas Functions to Select a Subset of the Dataset...

# %% [markdown]
# ### df.query() :

# %% [markdown]
# * This function is used to query the DataFrame based on an expression. An expression can be as simple as   a single condition and as complex as a combination of multiple conditions. For instance, suppose you     want to retrieve all the rows df where the Quantity is more than 70. You simply need to pass this         condition as an expression, as shown below.

# %%
df.query("Quantity >70")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 6     2750410000999927504        73             242  Not Delivered
# 12    3882310000999938823        78             219      Delivered
# 16    2808810000999928088        96             115      Delivered
# 18    3105110000999931051        79             213      Delivered
# ...                   ...       ...             ...            ...
# 9985  1541410000999915414        92             230        Shipped
# 9990  4241810000999942418        94             211    Not Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9994  2301610000999923016        75             201  Not Delivered
# 9996  2385710000999923857        81             207      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.loc() :

# %% [markdown]
# * This function is a property of DataFrame that returns the group of rows and columns identified by their   labels or names. So you can access a row and column combination as below,

# %%
df.loc[200,'Sales_Manager']
# Out:
# 'Pablo'

# %% [markdown]
# ##### Pandas Functions to get Deeper Insights into the Dataset...

# %% [markdown]
# ### df.unique() :

# %% [markdown]
# * This function returns the list of unique values in a column or series. Instead of applying on complete   DataFrame, it works only on the selected single column. For example, you can see which different sales   managers are present in the dataset using this function as below,

# %%
df["Product_Category"].unique()
# Out:
# array(['Healthcare', 'Office', 'Fashion', 'Entertainment', 'Home', nan],
#       dtype=object)

# %% [markdown]
# ### 	df.nunique() :

# %% [markdown]
# * In pandas, the df.nunique() method is used to calculate the number of unique values in each column of a   data frame. It returns a series containing the count of unique values for each column, with the column   names as the index.

# %%
df.nunique()
# Out:
# OrderID                8842
# Quantity                100
# UnitPrice(USD)          151
# Status                    4
# OrderDate               108
# Product_Category          5
# Sales_Manager            10
# Shipping_Cost(USD)       16
# Delivery_Time(Days)      16
# Shipping_Address          8
# Product_Code             30
# OrderCode               108
# dtype: int64

# %% [markdown]
# ### df.isnull() :

# %% [markdown]
# * The df.isnull() method in pandas is used to create a Boolean mask indicating where values are missing or null in a data frame. It returns a data frame of the same shape as the original data frame, where each element is either True if the corresponding value is null or False if it is not null.

# %%
df.isnull()
# Out:
#       OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  Product_Category  \
# 0       False     False           False   False      False             False
# 1       False     False           False   False      False             False
# 2       False     False           False   False      False             False
# 3       False     False           False   False      False             False
# 4       False     False           False   False      False             False
# ...       ...       ...             ...     ...        ...               ...
# 9994    False     False           False   False      False             False
# 9995    False     False           False   False      False             False
# 9996    False     False           False   False      False             False
# 9997    False     False           False   False      False             False
# 9998    False     False           False   False      False             False
#
# ...

# %% [markdown]
# ### df.fillna() :

# %% [markdown]
# * The df.fillna() method in pandas is used to fill missing or null values in a data frame with specified values. It returns a new data frame with the missing values replaced by the provided values.

# %%
df.fillna(2)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.sort_values() :

# %% [markdown]
# * The df.sort_values() method in pandas is used to sort a data frame by one or more columns. It returns a new data frame with the rows sorted based on the specified column. You can also sort by multiple columns by passing a list of column names to the by parameter.

# %%
df.sort_values("Quantity")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3367  4733210000999947332         1             213    Not Shipped
# 5952  2228310000999922283         1             203  Not Delivered
# 5569  3732610000999937326         1             165        Shipped
# 9516  2719510000999927195         1             247  Not Delivered
# 3429  3276610000999932766         1             157    Not Shipped
# ...                   ...       ...             ...            ...
# 7820  2478510000999924785       100             187      Delivered
# 2739  1262510000999912625       100             101        Shipped
# 551   3442310000999934423       100             218  Not Delivered
# 2719  2829410000999928294       100             117    Not Shipped
# 503   2085610000999920856       100             108  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3367  2021-07-04    Entertainment         Maria                  26
# ...

# %% [markdown]
# ### df.value_counts() :

# %% [markdown]
# * The df.value_counts() method in pandas is used to count the occurrences of unique values in a column or Series. It returns a new Series containing the count of each unique value, sorted in descending order by default.

# %%
df["Product_Category"].value_counts()
# Out:
# Home             2060
# Office           2011
# Fashion          1971
# Entertainment    1968
# Healthcare       1953
# Name: Product_Category, dtype: int64

# %% [markdown]
# ### df.nlargest() :

# %% [markdown]
# * The nlargest() method is helpful when you need to extract the top values based on a specific criterion, such as retrieving the highest sales, largest populations, or any other relevant metric from your dataset.

# %%
df.nlargest(5 , "Quantity")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 25   3063710000999930637       100             173  Not Delivered  2021-12-22
# 54   4861510000999948615       100             237        Shipped  2021-10-03
# 185  2768610000999927686       100             241    Not Shipped  2021-12-18
# 417  1015510000999910155       100             154  Not Delivered  2021-07-31
# 503  2085610000999920856       100             108  Not Delivered  2021-12-24
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 25            Office         Jacob                  21                 23.0
# 54            Office          John                  25                 13.0
# 185           Office       Kristen                  29                 12.0
# 417    Entertainment       Kristen                  33                 10.0
# 503       Healthcare       Kristen                  20                 19.0
#
# ...

# %% [markdown]
# ### df.nsmallest() :

# %% [markdown]
# * The df.nsmallest() method is useful when you need to extract the bottom values based on a specific criterion, such as retrieving the lowest prices, smallest quantities, or any other relevant metric from your dataset.

# %%
df.nsmallest(5 , "Quantity")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 27   4956110000999949561         1             154  Not Shipped  2021-10-04
# 29   3348510000999933485         1             212    Delivered  2021-12-18
# 56   3594610000999935946         1             196    Delivered  2021-11-11
# 326  2549410000999925494         1             126    Delivered  2021-10-10
# 338  1074510000999910745         1             249      Shipped  2021-08-14
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 27           Fashion         Pablo                  26                 23.0
# 29              Home         Sofia                  31                 24.0
# 56        Healthcare          John                  35                 21.0
# 326          Fashion       Kristen                  24                 12.0
# 338             Home         Sofia                  27                 18.0
#
#     Shipping_Address Product_Code  OrderCode
# ...

# %% [markdown]
# ##### Pandas Functions to Modify the Dataset...

# %% [markdown]
# ### df.copy() :

# %% [markdown]
# * The df.copy() method in pandas is used to create a copy of a data frame. It returns a new data frame object that is a deep copy of the original data frame, including the data and the index. Creating a copy of a data frame can consume additional memory, so it's recommended to use it only when necessary, particularly for large datasets.

# %%
df.copy()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.rename() :

# %% [markdown]
# * The df.rename() method in pandas is used to change the names of columns or index labels in a data frame. It's important to note that df.rename() returns a new data frame with the updated names, leaving the original data frame unchanged. If you want to modify the data frame in place, you can set the inplace = True parameter.

# %%
df.rename(columns= {"OrderID" : "Customer Id" , "OrderDate" : "Date"})
# Out:
#               Customer Id  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#             Date Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.where() :

# %% [markdown]
# * In the context of datasets, the df.where() method is typically used in pandas, a popular data manipulation library in Python. The df.where() function allows you to selectively update values in a data frame based on a specified condition, while keeping the original structure of the data frame intact.

# %%
condition = df["Quantity"] > 50
result = df.where(condition , other = 1 )
result
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3                       1         1               1              1
# 4                       1         1               1              1
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995                    1         1               1              1
# 9996  2385710000999923857        81             207      Delivered
# 9997                    1         1               1              1
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# ### df.drop() :

# %% [markdown]
# * In the context of datasets, the df.where() method is typically used in pandas, a popular data manipulation library in Python. The df.where() function allows you to selectively update values in a data frame based on a specified condition, while keeping the original structure of the data frame intact.

# %%
df.drop(['Quantity'], axis=1, inplace=True)
df
# Out:
#                   OrderID  UnitPrice(USD)         Status   OrderDate  \
# 0     2951110000999929511             238  Not Delivered  2021-08-08
# 1     2181910000999921819             136  Not Delivered  2021-10-03
# 2     3239110000999932391             235  Not Delivered  2021-09-27
# 3     1112610000999911126             133    Not Shipped  2021-07-30
# 4     1548310000999915483             189  Not Delivered  2021-08-15
# ...                   ...             ...            ...         ...
# 9994  2301610000999923016             201  Not Delivered  2021-10-16
# 9995  1847410000999918474             135        Shipped  2021-10-03
# 9996  2385710000999923857             207      Delivered  2021-11-13
# 9997  2281610000999922816             117        Shipped  2021-12-23
# 9998  1468010000999914680             229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %% [markdown]
# ##### Pandas Function to Understand the Relationship Between all Columns...

# %% [markdown]
# ### df.corr() :

# %% [markdown]
# * In the context of datasets, the df.corr() method is used in pandas, a popular data manipulation library in Python, to calculate the correlation between columns in a data frame. The df.corr() function computes the pairwise correlation of columns, generating a correlation matrix as its output.

# %%
result = df.corr()
result
# Out:
#                       OrderID  Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# OrderID              1.000000  0.008028        0.000866           -0.002899
# Quantity             0.008028  1.000000       -0.007948           -0.008935
# UnitPrice(USD)       0.000866 -0.007948        1.000000           -0.002698
# Shipping_Cost(USD)  -0.002899 -0.008935       -0.002698            1.000000
# Delivery_Time(Days) -0.017483 -0.003023       -0.013938           -0.004026
# OrderCode            0.005441 -0.002827        0.015882            0.008126
#
#                      Delivery_Time(Days)  OrderCode
# OrderID                        -0.017483   0.005441
# Quantity                       -0.003023  -0.002827
# UnitPrice(USD)                 -0.013938   0.015882
# Shipping_Cost(USD)             -0.004026   0.008126
# Delivery_Time(Days)             1.000000   0.008851
# OrderCode                       0.008851   1.000000
